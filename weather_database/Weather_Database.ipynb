# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
from citipy import citipy
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitudes
lats = np.random.uniform(-90,90,size=2000)
lngs = np.random.uniform(-180,180,size=2000)
lat_lngs = zip(lats,lngs)
coordinates = list(lat_lngs)

# %%
# Create a list for storing the cities
cities = []
# Identify the enarest city for each latitude and longitude
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    # If the city is new, add it to the cities list
    if city not in cities:
        cities.append(city)
# See how many cities are in list
len(cities)
# Out:
# 724

# %%
# weather API url 
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold weather data
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL record and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"] 
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tocopilla
# Processing Record 2 of Set 1 | olafsvik
# Processing Record 3 of Set 1 | arica
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | ghanzi
# Processing Record 8 of Set 1 | arkadak
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | bartica
# Processing Record 11 of Set 1 | new norfolk
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 1 | carnarvon
# Processing Record 16 of Set 1 | east london
# Processing Record 17 of Set 1 | kahului
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | parrita
# Processing Record 20 of Set 1 | namibe
# Processing Record 21 of Set 1 | omsukchan
# Processing Record 22 of Set 1 | iqaluit
# Processing Record 23 of Set 1 | muhos
# Processing Record 24 of Set 1 | cuenca
# Processing Record 25 of Set 1 | lasa
# Processing Record 26 of Set 1 | luderitz
# Processing Record 27 of Set 1 | goderich
# Processing Record 28 of Set 1 | alofi
# Processing Record 29 of Set 1 | nosy varika
# Processing Record 30 of Set 1 | provideniya
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | tawnat
# City not found. Skipping...
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | kefamenanu
# Processing Record 39 of Set 1 | bandarbeyla
# Processing Record 40 of Set 1 | yuancheng
# Processing Record 41 of Set 1 | medicine hat
# Processing Record 42 of Set 1 | cap malheureux
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | high level
# Processing Record 45 of Set 1 | wajima
# Processing Record 46 of Set 1 | westport
# Processing Record 47 of Set 1 | calvinia
# Processing Record 48 of Set 1 | egvekinot
# Processing Record 49 of Set 1 | hofn
# Processing Record 50 of Set 1 | sitka
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | bolshoy uluy
# City not found. Skipping...
# Processing Record 3 of Set 2 | mubi
# Processing Record 4 of Set 2 | salalah
# Processing Record 5 of Set 2 | khatanga
# Processing Record 6 of Set 2 | klaksvik
# Processing Record 7 of Set 2 | shiraz
# Processing Record 8 of Set 2 | mizdah
# Processing Record 9 of Set 2 | kaitangata
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | lorengau
# Processing Record 12 of Set 2 | caravelas
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | lucapa
# Processing Record 15 of Set 2 | arkhangelskoye
# Processing Record 16 of Set 2 | nishihara
# Processing Record 17 of Set 2 | seydi
# Processing Record 18 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 2 | pisco
# Processing Record 20 of Set 2 | ribeira grande
# Processing Record 21 of Set 2 | le vauclin
# Processing Record 22 of Set 2 | jiuquan
# Processing Record 23 of Set 2 | longyearbyen
# Processing Record 24 of Set 2 | lebu
# Processing Record 25 of Set 2 | kapaa
# Processing Record 26 of Set 2 | hithadhoo
# Processing Record 27 of Set 2 | airai
# Processing Record 28 of Set 2 | meulaboh
# Processing Record 29 of Set 2 | cap-aux-meules
# Processing Record 30 of Set 2 | severo-kurilsk
# Processing Record 31 of Set 2 | sangmelima
# Processing Record 32 of Set 2 | necochea
# Processing Record 33 of Set 2 | porto santo
# Processing Record 34 of Set 2 | castro
# Processing Record 35 of Set 2 | verkhnyaya sinyachikha
# Processing Record 36 of Set 2 | povenets
# Processing Record 37 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 2 | komsomolskiy
# Processing Record 39 of Set 2 | marawi
# Processing Record 40 of Set 2 | katherine
# Processing Record 41 of Set 2 | saint-philippe
# Processing Record 42 of Set 2 | inirida
# Processing Record 43 of Set 2 | san quintin
# Processing Record 44 of Set 2 | talnakh
# Processing Record 45 of Set 2 | gravdal
# Processing Record 46 of Set 2 | vaini
# Processing Record 47 of Set 2 | taltal
# Processing Record 48 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 2 | adrar
# Processing Record 50 of Set 2 | beloha
# Processing Record 1 of Set 3 | novobiryusinskiy
# Processing Record 2 of Set 3 | beringovskiy
# Processing Record 3 of Set 3 | bredasdorp
# Processing Record 4 of Set 3 | dunedin
# Processing Record 5 of Set 3 | shalyhyne
# Processing Record 6 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 3 | tura
# Processing Record 8 of Set 3 | quatre cocos
# Processing Record 9 of Set 3 | pevek
# Processing Record 10 of Set 3 | rabo de peixe
# Processing Record 11 of Set 3 | bonfim
# Processing Record 12 of Set 3 | puerto ayora
# Processing Record 13 of Set 3 | nikolskoye
# Processing Record 14 of Set 3 | saldanha
# Processing Record 15 of Set 3 | mar del plata
# Processing Record 16 of Set 3 | hami
# Processing Record 17 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 3 | north platte
# Processing Record 19 of Set 3 | huarmey
# Processing Record 20 of Set 3 | faanui
# Processing Record 21 of Set 3 | cidreira
# Processing Record 22 of Set 3 | wanaka
# Processing Record 23 of Set 3 | port lincoln
# Processing Record 24 of Set 3 | hovd
# Processing Record 25 of Set 3 | nabire
# Processing Record 26 of Set 3 | karratha
# Processing Record 27 of Set 3 | celendin
# Processing Record 28 of Set 3 | aguimes
# Processing Record 29 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 3 | jamestown
# Processing Record 31 of Set 3 | benicarlo
# Processing Record 32 of Set 3 | naryan-mar
# Processing Record 33 of Set 3 | mahebourg
# Processing Record 34 of Set 3 | fortuna
# Processing Record 35 of Set 3 | hamilton
# Processing Record 36 of Set 3 | sao filipe
# Processing Record 37 of Set 3 | labuhan
# Processing Record 38 of Set 3 | bongor
# Processing Record 39 of Set 3 | solnechnyy
# Processing Record 40 of Set 3 | hilo
# Processing Record 41 of Set 3 | georgetown
# Processing Record 42 of Set 3 | pingshan
# Processing Record 43 of Set 3 | hopelchen
# Processing Record 44 of Set 3 | we
# City not found. Skipping...
# Processing Record 45 of Set 3 | tiksi
# Processing Record 46 of Set 3 | nayoro
# Processing Record 47 of Set 3 | ballina
# Processing Record 48 of Set 3 | butaritari
# Processing Record 49 of Set 3 | norman wells
# Processing Record 50 of Set 3 | mount isa
# Processing Record 1 of Set 4 | skwierzyna
# Processing Record 2 of Set 4 | zhanjiang
# Processing Record 3 of Set 4 | poquoson
# Processing Record 4 of Set 4 | constitucion
# Processing Record 5 of Set 4 | ancud
# Processing Record 6 of Set 4 | broome
# Processing Record 7 of Set 4 | gurgan
# City not found. Skipping...
# Processing Record 8 of Set 4 | dikson
# Processing Record 9 of Set 4 | enshi
# Processing Record 10 of Set 4 | mana
# Processing Record 11 of Set 4 | khandyga
# Processing Record 12 of Set 4 | tuktoyaktuk
# Processing Record 13 of Set 4 | piryetos
# City not found. Skipping...
# Processing Record 14 of Set 4 | mokhsogollokh
# Processing Record 15 of Set 4 | dulovo
# Processing Record 16 of Set 4 | muros
# Processing Record 17 of Set 4 | nicoya
# Processing Record 18 of Set 4 | mehamn
# Processing Record 19 of Set 4 | lagoa
# Processing Record 20 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 21 of Set 4 | touba
# Processing Record 22 of Set 4 | ketchikan
# Processing Record 23 of Set 4 | udachnyy
# Processing Record 24 of Set 4 | kruisfontein
# Processing Record 25 of Set 4 | yamada
# Processing Record 26 of Set 4 | tessalit
# Processing Record 27 of Set 4 | amapa
# Processing Record 28 of Set 4 | umm durman
# City not found. Skipping...
# Processing Record 29 of Set 4 | san patricio
# Processing Record 30 of Set 4 | qaanaaq
# Processing Record 31 of Set 4 | yatou
# Processing Record 32 of Set 4 | surin
# Processing Record 33 of Set 4 | haines junction
# Processing Record 34 of Set 4 | bethel
# Processing Record 35 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 4 | thompson
# Processing Record 37 of Set 4 | peniche
# Processing Record 38 of Set 4 | shagonar
# Processing Record 39 of Set 4 | ampanihy
# Processing Record 40 of Set 4 | ixtapa
# Processing Record 41 of Set 4 | ayan
# Processing Record 42 of Set 4 | nanortalik
# Processing Record 43 of Set 4 | saurimo
# Processing Record 44 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 4 | bengkulu
# Processing Record 46 of Set 4 | vanavara
# Processing Record 47 of Set 4 | jalu
# Processing Record 48 of Set 4 | humberto de campos
# Processing Record 49 of Set 4 | dobryanka
# Processing Record 50 of Set 4 | cascais
# Processing Record 1 of Set 5 | dodge city
# Processing Record 2 of Set 5 | cabo san lucas
# Processing Record 3 of Set 5 | ishigaki
# Processing Record 4 of Set 5 | upernavik
# Processing Record 5 of Set 5 | vila franca do campo
# Processing Record 6 of Set 5 | raudeberg
# Processing Record 7 of Set 5 | amarante do maranhao
# Processing Record 8 of Set 5 | gat
# Processing Record 9 of Set 5 | lyuban
# Processing Record 10 of Set 5 | arcos
# Processing Record 11 of Set 5 | montepuez
# Processing Record 12 of Set 5 | saskylakh
# Processing Record 13 of Set 5 | seoul
# Processing Record 14 of Set 5 | salamanca
# Processing Record 15 of Set 5 | kalabo
# Processing Record 16 of Set 5 | fonte boa
# Processing Record 17 of Set 5 | pandan
# Processing Record 18 of Set 5 | saint austell
# Processing Record 19 of Set 5 | nikki
# Processing Record 20 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 5 | sept-iles
# Processing Record 22 of Set 5 | mandali
# Processing Record 23 of Set 5 | trinidad
# Processing Record 24 of Set 5 | boffa
# Processing Record 25 of Set 5 | machiques
# Processing Record 26 of Set 5 | keti bandar
# Processing Record 27 of Set 5 | victoria
# Processing Record 28 of Set 5 | umm lajj
# Processing Record 29 of Set 5 | kansanshi
# Processing Record 30 of Set 5 | torbay
# Processing Record 31 of Set 5 | svetlogorsk
# Processing Record 32 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 5 | chuy
# Processing Record 34 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 35 of Set 5 | puerto escondido
# Processing Record 36 of Set 5 | yidu
# Processing Record 37 of Set 5 | clyde river
# Processing Record 38 of Set 5 | vostok
# Processing Record 39 of Set 5 | sampit
# Processing Record 40 of Set 5 | batemans bay
# Processing Record 41 of Set 5 | varhaug
# Processing Record 42 of Set 5 | cherskiy
# Processing Record 43 of Set 5 | guerrero negro
# Processing Record 44 of Set 5 | bangassou
# Processing Record 45 of Set 5 | shache
# Processing Record 46 of Set 5 | rawson
# Processing Record 47 of Set 5 | nador
# Processing Record 48 of Set 5 | eureka
# Processing Record 49 of Set 5 | laguna
# Processing Record 50 of Set 5 | kerema
# Processing Record 1 of Set 6 | port hardy
# Processing Record 2 of Set 6 | mustafakemalpasa
# Processing Record 3 of Set 6 | aklavik
# Processing Record 4 of Set 6 | kholtoson
# Processing Record 5 of Set 6 | qasigiannguit
# Processing Record 6 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 6 | ostrovnoy
# Processing Record 8 of Set 6 | pirgos
# Processing Record 9 of Set 6 | esperance
# Processing Record 10 of Set 6 | burgeo
# Processing Record 11 of Set 6 | flinders
# Processing Record 12 of Set 6 | opobo
# City not found. Skipping...
# Processing Record 13 of Set 6 | tete
# Processing Record 14 of Set 6 | yinchuan
# Processing Record 15 of Set 6 | kangaatsiaq
# Processing Record 16 of Set 6 | ust-koksa
# Processing Record 17 of Set 6 | sao joao da barra
# Processing Record 18 of Set 6 | codrington
# Processing Record 19 of Set 6 | salaberry-de-valleyfield
# Processing Record 20 of Set 6 | boras
# Processing Record 21 of Set 6 | ninotsminda
# Processing Record 22 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 6 | lompoc
# Processing Record 24 of Set 6 | baymak
# Processing Record 25 of Set 6 | ilhabela
# Processing Record 26 of Set 6 | borlange
# City not found. Skipping...
# Processing Record 27 of Set 6 | vanimo
# Processing Record 28 of Set 6 | ilulissat
# Processing Record 29 of Set 6 | manubul
# Processing Record 30 of Set 6 | saint-marc
# Processing Record 31 of Set 6 | kita
# Processing Record 32 of Set 6 | lobito
# Processing Record 33 of Set 6 | sinnamary
# Processing Record 34 of Set 6 | buta
# Processing Record 35 of Set 6 | tuyen quang
# Processing Record 36 of Set 6 | bilma
# Processing Record 37 of Set 6 | homer
# Processing Record 38 of Set 6 | katsuura
# Processing Record 39 of Set 6 | atasu
# Processing Record 40 of Set 6 | sabha
# Processing Record 41 of Set 6 | bourail
# Processing Record 42 of Set 6 | corleone
# Processing Record 43 of Set 6 | osmaniye
# Processing Record 44 of Set 6 | nongstoin
# Processing Record 45 of Set 6 | aberdeen
# Processing Record 46 of Set 6 | massakory
# Processing Record 47 of Set 6 | itarema
# Processing Record 48 of Set 6 | trat
# Processing Record 49 of Set 6 | dickinson
# Processing Record 50 of Set 6 | san felipe
# Processing Record 1 of Set 7 | itoman
# Processing Record 2 of Set 7 | moultrie
# Processing Record 3 of Set 7 | atar
# Processing Record 4 of Set 7 | macia
# Processing Record 5 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 7 | jasidih
# Processing Record 7 of Set 7 | faya
# Processing Record 8 of Set 7 | kodiak
# Processing Record 9 of Set 7 | tiznit
# Processing Record 10 of Set 7 | dhidhdhoo
# Processing Record 11 of Set 7 | teguise
# Processing Record 12 of Set 7 | kavieng
# Processing Record 13 of Set 7 | riyadh
# Processing Record 14 of Set 7 | baghdad
# Processing Record 15 of Set 7 | ocos
# Processing Record 16 of Set 7 | vila velha
# Processing Record 17 of Set 7 | touros
# Processing Record 18 of Set 7 | shetpe
# Processing Record 19 of Set 7 | tasiilaq
# Processing Record 20 of Set 7 | mitsamiouli
# Processing Record 21 of Set 7 | natal
# Processing Record 22 of Set 7 | gwadar
# Processing Record 23 of Set 7 | punuare
# Processing Record 24 of Set 7 | valparaiso
# Processing Record 25 of Set 7 | ahuimanu
# Processing Record 26 of Set 7 | khash
# Processing Record 27 of Set 7 | arlit
# Processing Record 28 of Set 7 | sorland
# Processing Record 29 of Set 7 | ust-omchug
# Processing Record 30 of Set 7 | chahal
# Processing Record 31 of Set 7 | sisimiut
# Processing Record 32 of Set 7 | saint-joseph
# Processing Record 33 of Set 7 | vardo
# Processing Record 34 of Set 7 | uthal
# Processing Record 35 of Set 7 | yulara
# Processing Record 36 of Set 7 | barcelos
# Processing Record 37 of Set 7 | chickasha
# Processing Record 38 of Set 7 | kibre mengist
# Processing Record 39 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 7 | zyryanskoye
# Processing Record 41 of Set 7 | nome
# Processing Record 42 of Set 7 | bambous virieux
# Processing Record 43 of Set 7 | turayf
# Processing Record 44 of Set 7 | santa lucia
# Processing Record 45 of Set 7 | san cristobal
# Processing Record 46 of Set 7 | tuatapere
# Processing Record 47 of Set 7 | isangel
# Processing Record 48 of Set 7 | altamira
# Processing Record 49 of Set 7 | okhotsk
# Processing Record 50 of Set 7 | nyakahanga
# Processing Record 1 of Set 8 | hobyo
# Processing Record 2 of Set 8 | caxito
# Processing Record 3 of Set 8 | basna
# Processing Record 4 of Set 8 | tigzirt
# Processing Record 5 of Set 8 | yenagoa
# Processing Record 6 of Set 8 | darovskoy
# Processing Record 7 of Set 8 | bereda
# Processing Record 8 of Set 8 | sobolevo
# Processing Record 9 of Set 8 | ponta do sol
# Processing Record 10 of Set 8 | lazaro cardenas
# Processing Record 11 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 12 of Set 8 | riviere-au-renard
# Processing Record 13 of Set 8 | ilo
# Processing Record 14 of Set 8 | skjervoy
# Processing Record 15 of Set 8 | hasaki
# Processing Record 16 of Set 8 | magalia
# Processing Record 17 of Set 8 | mokrous
# Processing Record 18 of Set 8 | nenjiang
# Processing Record 19 of Set 8 | datong
# Processing Record 20 of Set 8 | liverpool
# Processing Record 21 of Set 8 | moosburg
# Processing Record 22 of Set 8 | parsabad
# Processing Record 23 of Set 8 | pasinler
# Processing Record 24 of Set 8 | xining
# Processing Record 25 of Set 8 | boa vista
# Processing Record 26 of Set 8 | kroya
# Processing Record 27 of Set 8 | aleksandrovskoye
# Processing Record 28 of Set 8 | polva
# Processing Record 29 of Set 8 | pahrump
# Processing Record 30 of Set 8 | taoudenni
# Processing Record 31 of Set 8 | khani
# Processing Record 32 of Set 8 | buin
# Processing Record 33 of Set 8 | mianyang
# Processing Record 34 of Set 8 | ville-marie
# Processing Record 35 of Set 8 | klyuchi
# Processing Record 36 of Set 8 | areosa
# Processing Record 37 of Set 8 | canon city
# Processing Record 38 of Set 8 | wakkanai
# Processing Record 39 of Set 8 | wewak
# Processing Record 40 of Set 8 | takaka
# Processing Record 41 of Set 8 | vestmanna
# Processing Record 42 of Set 8 | limbang
# Processing Record 43 of Set 8 | nuevo casas grandes
# Processing Record 44 of Set 8 | bathsheba
# Processing Record 45 of Set 8 | mariental
# Processing Record 46 of Set 8 | bosaso
# Processing Record 47 of Set 8 | kropotkin
# Processing Record 48 of Set 8 | ardakan
# Processing Record 49 of Set 8 | bathurst
# Processing Record 50 of Set 8 | yhu
# Processing Record 1 of Set 9 | black river
# Processing Record 2 of Set 9 | husavik
# Processing Record 3 of Set 9 | san severo
# Processing Record 4 of Set 9 | olutanga
# Processing Record 5 of Set 9 | tadine
# Processing Record 6 of Set 9 | tambun
# Processing Record 7 of Set 9 | cockburn town
# Processing Record 8 of Set 9 | kudahuvadhoo
# Processing Record 9 of Set 9 | san martin
# Processing Record 10 of Set 9 | santa rosalia
# Processing Record 11 of Set 9 | kitui
# Processing Record 12 of Set 9 | paracuru
# Processing Record 13 of Set 9 | porto velho
# Processing Record 14 of Set 9 | soyo
# Processing Record 15 of Set 9 | oistins
# Processing Record 16 of Set 9 | hambantota
# Processing Record 17 of Set 9 | meaux
# Processing Record 18 of Set 9 | price
# Processing Record 19 of Set 9 | broken hill
# Processing Record 20 of Set 9 | beidao
# Processing Record 21 of Set 9 | marzuq
# Processing Record 22 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 9 | mareeba
# Processing Record 24 of Set 9 | acatic
# Processing Record 25 of Set 9 | kavaratti
# Processing Record 26 of Set 9 | gordeyevka
# Processing Record 27 of Set 9 | alice springs
# Processing Record 28 of Set 9 | padang
# Processing Record 29 of Set 9 | kloulklubed
# Processing Record 30 of Set 9 | shambu
# Processing Record 31 of Set 9 | sakakah
# Processing Record 32 of Set 9 | sabzevar
# Processing Record 33 of Set 9 | awbari
# Processing Record 34 of Set 9 | porto novo
# Processing Record 35 of Set 9 | grindavik
# Processing Record 36 of Set 9 | mangochi
# Processing Record 37 of Set 9 | jinxiang
# Processing Record 38 of Set 9 | port-cartier
# Processing Record 39 of Set 9 | antofagasta
# Processing Record 40 of Set 9 | ottawa
# Processing Record 41 of Set 9 | arkadelphia
# Processing Record 42 of Set 9 | guymon
# Processing Record 43 of Set 9 | shuya
# Processing Record 44 of Set 9 | pyinmana
# Processing Record 45 of Set 9 | upington
# Processing Record 46 of Set 9 | chokurdakh
# Processing Record 47 of Set 9 | jacareacanga
# Processing Record 48 of Set 9 | vestmannaeyjar
# Processing Record 49 of Set 9 | partur
# Processing Record 50 of Set 9 | chapais
# Processing Record 1 of Set 10 | lao cai
# Processing Record 2 of Set 10 | polovinnoye
# Processing Record 3 of Set 10 | kautokeino
# Processing Record 4 of Set 10 | benghazi
# Processing Record 5 of Set 10 | george town
# Processing Record 6 of Set 10 | camacupa
# Processing Record 7 of Set 10 | mount gambier
# Processing Record 8 of Set 10 | bac lieu
# Processing Record 9 of Set 10 | saint george
# Processing Record 10 of Set 10 | chalmette
# Processing Record 11 of Set 10 | parlakimidi
# Processing Record 12 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 13 of Set 10 | ksenyevka
# City not found. Skipping...
# Processing Record 14 of Set 10 | sulangan
# Processing Record 15 of Set 10 | shimoda
# Processing Record 16 of Set 10 | bundaberg
# Processing Record 17 of Set 10 | charters towers
# Processing Record 18 of Set 10 | savannah bight
# Processing Record 19 of Set 10 | buraydah
# Processing Record 20 of Set 10 | paamiut
# Processing Record 21 of Set 10 | sur
# Processing Record 22 of Set 10 | shingu
# Processing Record 23 of Set 10 | laela
# Processing Record 24 of Set 10 | trincomalee
# Processing Record 25 of Set 10 | pasighat
# Processing Record 26 of Set 10 | havelock
# Processing Record 27 of Set 10 | tiarei
# Processing Record 28 of Set 10 | roald
# Processing Record 29 of Set 10 | mookane
# Processing Record 30 of Set 10 | abu jubayhah
# City not found. Skipping...
# Processing Record 31 of Set 10 | kakrala
# Processing Record 32 of Set 10 | mayumba
# Processing Record 33 of Set 10 | bowen
# Processing Record 34 of Set 10 | saveh
# Processing Record 35 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 10 | campina verde
# Processing Record 37 of Set 10 | najran
# Processing Record 38 of Set 10 | north bend
# Processing Record 39 of Set 10 | tawang
# Processing Record 40 of Set 10 | winnemucca
# Processing Record 41 of Set 10 | tanakpur
# Processing Record 42 of Set 10 | thurso
# Processing Record 43 of Set 10 | hay river
# Processing Record 44 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 10 | nizhniy tsasuchey
# Processing Record 46 of Set 10 | lavrentiya
# Processing Record 47 of Set 10 | tzucacab
# Processing Record 48 of Set 10 | nemuro
# Processing Record 49 of Set 10 | san onofre
# Processing Record 50 of Set 10 | bay roberts
# Processing Record 1 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 2 of Set 11 | namalenga
# Processing Record 3 of Set 11 | kosonsoy
# Processing Record 4 of Set 11 | olavarria
# Processing Record 5 of Set 11 | burkhala
# City not found. Skipping...
# Processing Record 6 of Set 11 | suileng
# Processing Record 7 of Set 11 | olean
# Processing Record 8 of Set 11 | qiryat gat
# Processing Record 9 of Set 11 | katima mulilo
# Processing Record 10 of Set 11 | nova olinda do norte
# Processing Record 11 of Set 11 | kichmengskiy gorodok
# Processing Record 12 of Set 11 | gannan
# Processing Record 13 of Set 11 | oktyabrskoye
# Processing Record 14 of Set 11 | kanker
# Processing Record 15 of Set 11 | arraial do cabo
# Processing Record 16 of Set 11 | stornoway
# Processing Record 17 of Set 11 | half moon bay
# Processing Record 18 of Set 11 | vigrestad
# Processing Record 19 of Set 11 | angoche
# Processing Record 20 of Set 11 | portland
# Processing Record 21 of Set 11 | college
# Processing Record 22 of Set 11 | nouakchott
# Processing Record 23 of Set 11 | warwick
# Processing Record 24 of Set 11 | hualmay
# Processing Record 25 of Set 11 | jagalur
# Processing Record 26 of Set 11 | hendijan
# City not found. Skipping...
# Processing Record 27 of Set 11 | notodden
# Processing Record 28 of Set 11 | mkushi
# Processing Record 29 of Set 11 | mahanoro
# Processing Record 30 of Set 11 | snezhnogorsk
# Processing Record 31 of Set 11 | pingzhuang
# Processing Record 32 of Set 11 | gold coast
# Processing Record 33 of Set 11 | bluefield
# Processing Record 34 of Set 11 | srednekolymsk
# Processing Record 35 of Set 11 | okahandja
# Processing Record 36 of Set 11 | baijiantan
# Processing Record 37 of Set 11 | vukovar
# Processing Record 38 of Set 11 | avaton
# Processing Record 39 of Set 11 | saint-francois
# Processing Record 40 of Set 11 | berlevag
# Processing Record 41 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 11 | ekimchan
# Processing Record 43 of Set 11 | ewa beach
# Processing Record 44 of Set 11 | ordynskoye
# Processing Record 45 of Set 11 | auki
# Processing Record 46 of Set 11 | nhulunbuy
# Processing Record 47 of Set 11 | coihaique
# Processing Record 48 of Set 11 | platteville
# Processing Record 49 of Set 11 | masvingo
# Processing Record 50 of Set 11 | rosarno
# Processing Record 1 of Set 12 | marsh harbour
# Processing Record 2 of Set 12 | guanica
# Processing Record 3 of Set 12 | presidencia roque saenz pena
# Processing Record 4 of Set 12 | suntar
# Processing Record 5 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 6 of Set 12 | egra
# Processing Record 7 of Set 12 | waipawa
# Processing Record 8 of Set 12 | chany
# Processing Record 9 of Set 12 | barlinek
# Processing Record 10 of Set 12 | pilar
# Processing Record 11 of Set 12 | kibala
# Processing Record 12 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 12 | dublin
# Processing Record 14 of Set 12 | coahuayana
# Processing Record 15 of Set 12 | biak
# Processing Record 16 of Set 12 | carballo
# Processing Record 17 of Set 12 | rio gallegos
# Processing Record 18 of Set 12 | jibuti
# Processing Record 19 of Set 12 | vallenar
# Processing Record 20 of Set 12 | miri
# Processing Record 21 of Set 12 | te anau
# Processing Record 22 of Set 12 | geraldton
# Processing Record 23 of Set 12 | dibaya
# City not found. Skipping...
# Processing Record 24 of Set 12 | powell river
# Processing Record 25 of Set 12 | puerto madryn
# Processing Record 26 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 12 | muscat
# Processing Record 28 of Set 12 | katsiveli
# City not found. Skipping...
# Processing Record 29 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 30 of Set 12 | gondar
# Processing Record 31 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 32 of Set 12 | qinzhou
# Processing Record 33 of Set 12 | santa maria do para
# Processing Record 34 of Set 12 | nyurba
# Processing Record 35 of Set 12 | mildura
# Processing Record 36 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 12 | baykit
# Processing Record 38 of Set 12 | brodokalmak
# Processing Record 39 of Set 12 | kapit
# Processing Record 40 of Set 12 | weyburn
# Processing Record 41 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 42 of Set 12 | port-gentil
# Processing Record 43 of Set 12 | lata
# Processing Record 44 of Set 12 | makakilo city
# Processing Record 45 of Set 12 | providencia
# Processing Record 46 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 12 | maua
# Processing Record 48 of Set 12 | fairbanks
# Processing Record 49 of Set 12 | xocali
# Processing Record 50 of Set 12 | trelew
# Processing Record 1 of Set 13 | nadym
# Processing Record 2 of Set 13 | atambua
# Processing Record 3 of Set 13 | araxa
# Processing Record 4 of Set 13 | slobodskoy
# Processing Record 5 of Set 13 | yumen
# Processing Record 6 of Set 13 | hanna
# Processing Record 7 of Set 13 | orchard homes
# Processing Record 8 of Set 13 | grimshaw
# Processing Record 9 of Set 13 | samsun
# Processing Record 10 of Set 13 | ruwi
# Processing Record 11 of Set 13 | kalomo
# City not found. Skipping...
# Processing Record 12 of Set 13 | balabac
# Processing Record 13 of Set 13 | abnub
# Processing Record 14 of Set 13 | whitehorse
# Processing Record 15 of Set 13 | pandharpur
# Processing Record 16 of Set 13 | puro
# Processing Record 17 of Set 13 | varzea grande
# Processing Record 18 of Set 13 | nizhniy kuranakh
# Processing Record 19 of Set 13 | moiyabana
# City not found. Skipping...
# Processing Record 20 of Set 13 | halifax
# Processing Record 21 of Set 13 | sorata
# Processing Record 22 of Set 13 | starobaltachevo
# Processing Record 23 of Set 13 | siyabuswa
# Processing Record 24 of Set 13 | kimbe
# Processing Record 25 of Set 13 | asau
# Processing Record 26 of Set 13 | xiamen
# Processing Record 27 of Set 13 | yar-sale
# Processing Record 28 of Set 13 | akyab
# Processing Record 29 of Set 13 | sungaipenuh
# Processing Record 30 of Set 13 | yarada
# Processing Record 31 of Set 13 | coquimbo
# Processing Record 32 of Set 13 | crotone
# Processing Record 33 of Set 13 | rabaul
# Processing Record 34 of Set 13 | sambava
# Processing Record 35 of Set 13 | chernyshevskiy
# Processing Record 36 of Set 13 | novikovo
# Processing Record 37 of Set 13 | rincon
# Processing Record 38 of Set 13 | buldana
# Processing Record 39 of Set 13 | kysyl-syr
# Processing Record 40 of Set 13 | lafia
# Processing Record 41 of Set 13 | moerai
# Processing Record 42 of Set 13 | bar harbor
# Processing Record 43 of Set 13 | iwanai
# Processing Record 44 of Set 13 | claresholm
# Processing Record 45 of Set 13 | wolmaranstad
# City not found. Skipping...
# Processing Record 46 of Set 13 | xinzhou
# Processing Record 47 of Set 13 | north augusta
# Processing Record 48 of Set 13 | nago
# Processing Record 49 of Set 13 | sechura
# Processing Record 50 of Set 13 | grojec
# Processing Record 1 of Set 14 | karamken
# City not found. Skipping...
# Processing Record 2 of Set 14 | leningradskiy
# Processing Record 3 of Set 14 | xiaoshi
# Processing Record 4 of Set 14 | ahipara
# Processing Record 5 of Set 14 | chara
# Processing Record 6 of Set 14 | maiduguri
# Processing Record 7 of Set 14 | uarini
# Processing Record 8 of Set 14 | vao
# Processing Record 9 of Set 14 | tautira
# Processing Record 10 of Set 14 | phan thiet
# Processing Record 11 of Set 14 | kurilsk
# Processing Record 12 of Set 14 | canete
# Processing Record 13 of Set 14 | narsaq
# Processing Record 14 of Set 14 | strelka
# Processing Record 15 of Set 14 | wagga wagga
# Processing Record 16 of Set 14 | kuito
# Processing Record 17 of Set 14 | llata
# Processing Record 18 of Set 14 | buluang
# Processing Record 19 of Set 14 | inhambane
# Processing Record 20 of Set 14 | oranjemund
# Processing Record 21 of Set 14 | capitan bado
# Processing Record 22 of Set 14 | yeppoon
# Processing Record 23 of Set 14 | sadowara
# City not found. Skipping...
# Processing Record 24 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 14 | petauke
# Processing Record 26 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 27 of Set 14 | ambon
# Processing Record 28 of Set 14 | mikhaylovka
# Processing Record 29 of Set 14 | teruel
# Processing Record 30 of Set 14 | erzin
# Processing Record 31 of Set 14 | damietta
# Processing Record 32 of Set 14 | osijek
# Processing Record 33 of Set 14 | susanville
# Processing Record 34 of Set 14 | vila
# Processing Record 35 of Set 14 | kitale
# Processing Record 36 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 37 of Set 14 | umm kaddadah
# Processing Record 38 of Set 14 | kharp
# Processing Record 39 of Set 14 | gombong
# Processing Record 40 of Set 14 | jiazi
# Processing Record 41 of Set 14 | blyznyuky
# Processing Record 42 of Set 14 | erenhot
# Processing Record 43 of Set 14 | aurora
# Processing Record 44 of Set 14 | tilichiki
# Processing Record 45 of Set 14 | jizan
# Processing Record 46 of Set 14 | villa sandino
# Processing Record 47 of Set 14 | santa ana
# Processing Record 48 of Set 14 | robertsport
# Processing Record 49 of Set 14 | camana
# Processing Record 50 of Set 14 | qingyuan
# Processing Record 1 of Set 15 | korla
# Processing Record 2 of Set 15 | kedgwick
# Processing Record 3 of Set 15 | yakeshi
# Processing Record 4 of Set 15 | souillac
# Processing Record 5 of Set 15 | guadalupe y calvo
# Processing Record 6 of Set 15 | cayenne
# Processing Record 7 of Set 15 | araouane
# Processing Record 8 of Set 15 | road town
# Processing Record 9 of Set 15 | sola
# Processing Record 10 of Set 15 | banjar
# Processing Record 11 of Set 15 | shizuishan
# Processing Record 12 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 13 of Set 15 | san francisco de macoris
# Processing Record 14 of Set 15 | launceston
# Processing Record 15 of Set 15 | aswan
# Processing Record 16 of Set 15 | camacha
# Processing Record 17 of Set 15 | krasnoselkup
# Processing Record 18 of Set 15 | ondjiva
# Processing Record 19 of Set 15 | baherden
# Processing Record 20 of Set 15 | dosso
# Processing Record 21 of Set 15 | contamana
# Processing Record 22 of Set 15 | nuuk
# Processing Record 23 of Set 15 | gizo
# Processing Record 24 of Set 15 | sheridan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City Country                 Date      Lat       Lng  Max Temp  \
# 0  Tocopilla      CL  2022-09-25 22:24:23 -22.0920  -70.1979     64.09
# 1   Olafsvik      IS  2022-09-25 22:24:24  64.8945  -23.7142     45.07
# 2      Arica      CL  2022-09-25 22:24:24 -18.4750  -70.3042     63.95
# 3    Rikitea      PF  2022-09-25 22:24:24 -23.1203 -134.9692     69.04
# 4     Barrow      US  2022-09-25 22:24:25  71.2906 -156.7887     32.02
# 5     Albany      US  2022-09-25 22:24:25  42.6001  -73.9662     64.38
# 6     Ghanzi      BW  2022-09-25 22:24:25 -21.5667   21.7833     75.20
# 7    Arkadak      RU  2022-09-25 22:24:25  51.9326   43.4978     45.57
# 8     Avarua      CK  2022-09-25 22:24:26 -21.2078 -159.7750     78.85
# 9    Bartica      GY  2022-09-25 22:24:26   6.4000  -58.6167     82.72
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        66          22       10.98          few clouds
# 1        62           1       10.96           clear sky
# 2        67           0       11.50           clear sky
# 3        59           0       15.50           clear sky
# 4        80         100       14.97          light snow
# 5        81          96        1.01     overcast clouds
# 6        20           0       11.56           clear sky
# 7        88         100       15.77     overcast clouds
# 8        73          75       13.80       broken clouds
# 9        93          68        1.72       broken clouds

# %%
# Create the output file
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City ID")
